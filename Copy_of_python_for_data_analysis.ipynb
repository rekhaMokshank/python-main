# %% [markdown]
# <a href="https://colab.research.google.com/github/rekhaMokshank/python-main/blob/main/Copy_of_python_for_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print("hello")
# Out:
# hello

# %%
# pandas - used for data understanding / preprocessing
# matplotlib - used for data visualization
# seaborn - used for data visualization
# plotly - used for data visualization (interactive graph)

# %%
# to work with the packages we will have to import it
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# load the data
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_train.csv")
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# what is the number of rows and no of columns in data
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# df

# %%
df.iloc[ 10 : 16  ]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2

# %%
df.loc[ 10 : 16  ]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
df.iloc[ 10 : 16  , 0 : 2  ]
# Out:
#     total_bill   tip
# 10       10.27  1.71
# 11       35.26  5.00
# 12       15.42  1.57
# 13       18.43  3.00
# 14       14.83  3.02
# 15       21.58  3.92

# %%
df.loc[ 10 : 16  , "total_bill" : "tip" ]
# Out:
#     total_bill   tip
# 10       10.27  1.71
# 11       35.26  5.00
# 12       15.42  1.57
# 13       18.43  3.00
# 14       14.83  3.02
# 15       21.58  3.92
# 16       10.33  1.67

# %%
df.loc[  :  , "total_bill" : "smoker" ]
# Out:
#      total_bill   tip     sex smoker
# 0         16.99  1.01  Female     No
# 1         10.34  1.66    Male     No
# 2         21.01  3.50    Male     No
# 3         23.68  3.31    Male     No
# 4         24.59  3.61  Female     No
# ..          ...   ...     ...    ...
# 239       29.03  5.92    Male     No
# 240       27.18  2.00  Female    Yes
# 241       22.67  2.00    Male    Yes
# 242       17.82  1.75    Male     No
# 243       18.78  3.00  Female     No
#
# [244 rows x 4 columns]

# %%
df.loc[  :  , 0 : 2 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_560/503066541.py in <cell line: 0>()
# ----> 1 df.loc[  :  , 0 : 2 ]
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1375             return self._multi_take(tup)
#    1376
# -> 1377         return self._getitem_tuple_same_dim(tup)
#    1378
#    1379     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
df[ ["total_bill","tip", "smoker"] ]
# Out:
#      total_bill   tip smoker
# 0         16.99  1.01     No
# 1         10.34  1.66     No
# 2         21.01  3.50     No
# 3         23.68  3.31     No
# 4         24.59  3.61     No
# ..          ...   ...    ...
# 239       29.03  5.92     No
# 240       27.18  2.00    Yes
# 241       22.67  2.00    Yes
# 242       17.82  1.75     No
# 243       18.78  3.00     No
#
# [244 rows x 3 columns]

# %%
#  We can do conditional filtering
df[df["tip"] > 2]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [166 rows x 7 columns]

# %%
df[(df['tip'] > 2)  & (df['smoker'] == "No")]  # for we use |
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [103 rows x 7 columns]

# %%
df.sort_values("tip", ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# ..          ...    ...     ...    ...   ...     ...   ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sort_values(["total_bill","tip"], ascending=[False, True])
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
# data corrections
# missing value handling
# outlier handling
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['size'] = df['size'].astype("category")
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size          category
# dtype: object

# %%
df['day'] = df['day'].astype(str)
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day             object
# time          category
# size          category
# dtype: object

# %%
df['total_payment'] = df['total_bill'] + df['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time size  total_payment
# 0       16.99  1.01  Female     No  Sun  Dinner    2          18.00
# 1       10.34  1.66    Male     No  Sun  Dinner    3          12.00
# 2       21.01  3.50    Male     No  Sun  Dinner    3          24.51
# 3       23.68  3.31    Male     No  Sun  Dinner    2          26.99
# 4       24.59  3.61  Female     No  Sun  Dinner    4          28.20

# %%
df = df.drop(columns = ['total_payment'])
df
# Out:
#      total_bill   tip     sex smoker   day    time size
# 0         16.99  1.01  Female     No   Sun  Dinner    2
# 1         10.34  1.66    Male     No   Sun  Dinner    3
# 2         21.01  3.50    Male     No   Sun  Dinner    3
# 3         23.68  3.31    Male     No   Sun  Dinner    2
# 4         24.59  3.61  Female     No   Sun  Dinner    4
# ..          ...   ...     ...    ...   ...     ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner    3
# 240       27.18  2.00  Female    Yes   Sat  Dinner    2
# 241       22.67  2.00    Male    Yes   Sat  Dinner    2
# 242       17.82  1.75    Male     No   Sat  Dinner    2
# 243       18.78  3.00  Female     No  Thur  Dinner    2
#
# [244 rows x 7 columns]

# %%
df.groupby(["sex","smoker"])["total_bill"].mean()
# Out:
# /tmp/ipykernel_560/2878175748.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["sex","smoker"])["total_bill"].mean()
# sex     smoker
# Male    Yes       22.284500
#         No        19.791237
# Female  Yes       17.977879
#         No        18.105185
# Name: total_bill, dtype: float64

# %%
# bar chart/ hist / scatterplot
# matplotlib / seaborn
s = df.groupby(["sex"])["total_bill"].mean()
s
# Out:
# /tmp/ipykernel_560/2224539613.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   s = df.groupby(["sex"])["total_bill"].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
plt.bar(s.index, s.values)
# Out:
# <BarContainer object of 2 artists>

# %%
sns.barplot(s)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
plt.hist(df['total_bill'],edgecolor='black')
plt.title("Toaal bill distribution")
plt.xlabel("Total bill")
plt.ylabel("Frequency")
plt.show()

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.scatter(df['total_bill'], df['tip'])

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df
